# %% [markdown]
# # Flight Passenger Analysis

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing Data

df_1 = pd.read_csv("C:\\Users\\dines\\Downloads\\Flight Passenger Analysis Using Python\\passenger data.csv")
df_2 = pd.read_csv("C:\\Users\\dines\\Downloads\\Flight Passenger Analysis Using Python\\survery data.csv")

# %% [markdown]
# ## Data Information

# %% [markdown]
# ### There are 2 csv files that are shared here.

# %% [markdown]
# **A.     Passenger Data**
# *      id - id assigned to the each customer
# *      Gender - Gender of customer
# *      Customer Type -
# *      Age - Age of customer
# *      Type of travel -
# *      Class -
# *      Flight Distance -

# %%
df_1.head()
# Out:
#        id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0  114960  Female  Loyal Customer   55  Business travel  Business
# 1   43337    Male  Loyal Customer   36  Business travel       Eco
# 2   74692  Female  Loyal Customer   17  Personal Travel       Eco
# 3   98299  Female  Loyal Customer   11  Personal Travel       Eco
# 4   70039    Male  Loyal Customer   39  Business travel       Eco
#
#    Flight Distance
# 0             2001
# 1              387
# 2             1235
# 3             1072
# 4              183

# %% [markdown]
# **B.      Survery Data**
# *        id -
# *        Inflight wifi service -
# *        Departure/Arrival time convenient -
# *        Ease of Online booking -
# *        Gate location -
# *        Food and drink -
# *        Online boarding -
# *        Seat comfort -
# *        Inflight entertainment -
# *        On-board service -
# *        Leg room service -
# *        Baggage handling -
# *        Checkin service -
# *        Inflight service -
# *        Cleanliness -
# *        Departure Delay in Minutes -
# *        Arrival Delay in Minutes -
# *        satisfaction -

# %%
df_2.head()
# Out:
#        id  Inflight wifi service  Departure/Arrival time convenient  \
# 0   70172                      3                                  4
# 1    5047                      3                                  2
# 2  110028                      2                                  2
# 3   24026                      2                                  5
# 4  119299                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
# Merging Datasets into a single Dataframe

df = pd.merge(left = df_1 , right = df_2 , how = "inner" , left_on = "id" , right_on = "id")

# %%
df.head()
# Out:
#        id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0  114960  Female  Loyal Customer   55  Business travel  Business
# 1  114960  Female  Loyal Customer   55  Business travel  Business
# 2   43337    Male  Loyal Customer   36  Business travel       Eco
# 3   43337    Male  Loyal Customer   36  Business travel       Eco
# 4   74692  Female  Loyal Customer   17  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             2001                      2                                  2
# 1             2001                      2                                  2
# 2              387                      3                                  5
# 3              387                      3                                  5
# 4             1235                      3                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
df.tail()
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 122449    2944  Female     Loyal Customer   49  Business travel  Business
# 122450   10732    Male     Loyal Customer   33  Business travel       Eco
# 122451   22247    Male     Loyal Customer   63  Business travel  Business
# 122452  102432  Female     Loyal Customer   28  Personal Travel       Eco
# 122453   74494    Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 122449             1813                      2
# 122450              158                      2
# 122451              143                      1
# 122452              223                      4
# 122453             1205                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 122449                                  2                       2  ...
# 122450                                  4                       4  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122454 entries, 0 to 122453
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 122454 non-null  int64
#  1   Gender                             122454 non-null  object
#  2   Customer Type                      122454 non-null  object
#  3   Age                                122454 non-null  int64
#  4   Type of Travel                     122454 non-null  object
#  5   Class                              122454 non-null  object
#  6   Flight Distance                    122454 non-null  int64
#  7   Inflight wifi service              122454 non-null  int64
#  8   Departure/Arrival time convenient  122454 non-null  int64
#  9   Ease of Online booking             122454 non-null  int64
#  10  Gate location                      122454 non-null  int64
# ...

# %%
# al the columns which are present in data
df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# ##### Data Cleaning

# %%
# dealing with missing values
df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             369
# ...

# %%
# Droping null values row
df.dropna( axis = 0 ,inplace = True)

# %%
df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# dealing with duplicates values
df.duplicated().sum()
# Out:
# 1451

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0       114960  Female     Loyal Customer   55  Business travel  Business
# 2        43337    Male     Loyal Customer   36  Business travel       Eco
# 4        74692  Female     Loyal Customer   17  Personal Travel       Eco
# 6        98299  Female     Loyal Customer   11  Personal Travel       Eco
# 8        70039    Male     Loyal Customer   39  Business travel       Eco
# ...        ...     ...                ...  ...              ...       ...
# 122449    2944  Female     Loyal Customer   49  Business travel  Business
# 122450   10732    Male     Loyal Customer   33  Business travel       Eco
# 122451   22247    Male     Loyal Customer   63  Business travel  Business
# 122452  102432  Female     Loyal Customer   28  Personal Travel       Eco
# 122453   74494    Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
df.shape
# Out:
# (120634, 24)

# %%
# Set id as index
df = df.set_index("id")

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 114960  Female     Loyal Customer   55  Business travel  Business
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 74692   Female     Loyal Customer   17  Personal Travel       Eco
# 98299   Female     Loyal Customer   11  Personal Travel       Eco
# 70039     Male     Loyal Customer   39  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 2944    Female     Loyal Customer   49  Business travel  Business
# 10732     Male     Loyal Customer   33  Business travel       Eco
# 22247     Male     Loyal Customer   63  Business travel  Business
# 102432  Female     Loyal Customer   28  Personal Travel       Eco
# 74494     Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 114960             2001                      2
# 43337               387                      3
# ...

# %%
df.shape
# Out:
# (120634, 23)

# %%
# Checking for datatypes for each variable
df.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
# Adding a new column as Satisfaction
df = df.replace({"satisfaction" : {"satisfied" : "Yes" , "neutral or dissatisfied" : "No"}})

# %% [markdown]
# ###### Statistical analysis

# %%
df["Departure Delay in Minutes"].mean()
# Out:
# 15.050516438151766

# %%
df["Arrival Delay in Minutes"].mean()
# Out:
# 15.434031864980023

# %% [markdown]
# * Average Departure Delay : **15.05 Minutes**
# * Average Arrival Delay : **15.43 Minutes**

# %%
df["Departure/Arrival time convenient"].mean()
# Out:
# 3.0601820382313445

# %%
ratingList = ["Departure/Arrival time convenient","Ease of Online booking","Gate location","Food and drink","Online boarding","Seat comfort","Inflight entertainment","On-board service","Leg room service","Baggage handling","Checkin service","Inflight service","Cleanliness"]

# %%
for i in ratingList:
    print("rating",df[i].mean())
# Out:
# 3.0601820382313445
# 2.756171560256644
# 2.977278379229736
# 3.2048924847058045
# 3.2476250476648376
# 3.436800570320142
# 3.358505893860769
# 3.3787240744732
# 3.3478455493476136
# 3.625437273073926
# 3.2996087338561266
# 3.637042624798979
# 3.2857569176185817

# %%
#fig, a = plt.subplots(2,2)
plt.figure(figsize=(20,20))
plt.subplot(5,3,1).set_title("Inflight wifi service Rating")
plt.bar(df["Inflight wifi service"].unique(),df["Inflight wifi service"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,2).set_title("Departure/Arrival time convenientRating")
plt.bar(df["Departure/Arrival time convenient"].unique(),df["Departure/Arrival time convenient"].value_counts(),color = "g",edgecolor='r')
plt.subplot(5,3,3).set_title("Ease of Online booking Rating")
plt.bar(df["Ease of Online booking"].unique(),df["Ease of Online booking"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,4).set_title("Gate location Rating")
plt.bar(df["Gate location"].unique(),df["Gate location"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,5).set_title("Food and drink Rating")
plt.bar(df["Food and drink"].unique(),df["Food and drink"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,6).set_title("Online boarding Rating")
plt.bar(df["Online boarding"].unique(),df["Online boarding"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,7).set_title("Seat comfort Rating")
plt.bar(df["Seat comfort"].unique(),df["Seat comfort"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,8).set_title("Inflight entertainment Rating")
plt.bar(df["Inflight entertainment"].unique(),df["Inflight entertainment"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,9).set_title("On-board service Rating")
plt.bar(df["On-board service"].unique(),df["On-board service"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,10).set_title("Leg room service Rating")
plt.bar(df["Leg room service"].unique(),df["Leg room service"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,11).set_title("Baggage handling Rating")
plt.bar(df["Baggage handling"].unique(),df["Baggage handling"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,12).set_title("Checkin service Rating")
plt.bar(df["Checkin service"].unique(),df["Checkin service"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,13).set_title("Inflight service Rating")
plt.bar(df["Inflight service"].unique(),df["Inflight service"].value_counts(),color = "b",edgecolor='r')
plt.subplot(5,3,14).set_title("Cleanliness Rating")
plt.bar(df["Cleanliness"].unique(),df["Cleanliness"].value_counts(),color = "b",edgecolor='r')

plt.show()

# %%
plt.pie(df["Customer Type"].value_counts(), labels =df["Customer Type"].unique(), autopct='%1.0f%%')
plt.show()

# %%
plt.pie(df["Class"].value_counts(), labels =df["Class"].unique(), autopct='%1.0f%%')
plt.show()

# %%
sns.countplot(df.satisfaction, hue=df.Gender)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# let's Distinguish the data by passenger Type of travel
sns.countplot(df.satisfaction, hue=df['Type of Travel'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["Cleanliness"].value_counts()
# Out:
# 4    31511
# 3    28346
# 5    26453
# 2    18717
# 1    15593
# 0       14
# Name: Cleanliness, dtype: int64

# %%
df["Type of Travel"].unique()
# Out:
# array(['Business travel', 'Personal Travel'], dtype=object)

# %%
plt.bar(df["Age"].unique(),df["Age"].value_counts(),color ='b',width = 0.4,bottom=10,align ='center',linewidth=2)
plt.show()

# %%
df["Age_grpup"]=pd.cut( df['Age'], bins=[10, 20, 30, 40, 50, 60, 70, 80, 90 ],labels = ["group1","g2","g3","g4","g5","g6","g7","g8"])

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 114960  Female     Loyal Customer   55  Business travel  Business
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 74692   Female     Loyal Customer   17  Personal Travel       Eco
# 98299   Female     Loyal Customer   11  Personal Travel       Eco
# 70039     Male     Loyal Customer   39  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 2944    Female     Loyal Customer   49  Business travel  Business
# 10732     Male     Loyal Customer   33  Business travel       Eco
# 22247     Male     Loyal Customer   63  Business travel  Business
# 102432  Female     Loyal Customer   28  Personal Travel       Eco
# 74494     Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 114960             2001                      2
# 43337               387                      3
# ...

# %%
#plt.bar(df["Age_grpup"].unique(),df["Age_grpup"].value_counts())
#plt.bar(df["Age_grpup"].unique(),df["Age_grpup"].value_counts(),color = "b",edgecolor='r')

df["Age_grpup"].value_counts()
# Out:
# g4        26950
# g2        24951
# g3        24599
# g5        21770
# group1    10122
# g6         8390
# g7          899
# g8           23
# Name: Age_grpup, dtype: int64

# %%
sns.countplot(data=df, x="Age_grpup")
# Out:
# <AxesSubplot:xlabel='Age_grpup', ylabel='count'>

# %%
df[["Age_grpup","Age"]].loc[df["Age_grpup"] == "group1"].min()
# Out:
# Age_grpup    group1
# Age              11
# dtype: object
